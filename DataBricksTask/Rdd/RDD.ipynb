# %%
import os
print(os.environ['SPARK_HOME'])
print(os.environ['JAVA_HOME'])
print(os.environ['PATH'])
# Out:
# /databricks/spark
# /usr/lib/jvm/zulu8-ca-amd64/jre/
# /usr/local/nvidia/bin:/databricks/python3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/snap/bin

# %%
import pyspark
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Python Spark SQL basic example").config("spark.driver.cores","1").config("spark.driver.memory","1g")     .config("spark.executor.cores","2").config("spark.executor.memory","1gb").config("spark.num.executors","2").enableHiveSupport().getOrCreate()
    
sc = spark.sparkContext

# %%
nums = sc.parallelize([1,2,3,4])

# %%
squares = nums.map(lambda x: x*x)
even = nums.filter(lambda x: x%2==0)
merged = nums.reduce(lambda x, y: x+y)

# %%
print(squares.collect())
# Out:
# [1, 4, 9, 16]

# %%
print(even.collect())
# Out:
# [2, 4]

# %%
nums.take(2)
# Out:
# Out[11]: [1, 2]

# %%
nums.count()
# Out:
# Out[12]: 4

# %%
print(merged)
# Out:
# 10
